# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
store_cleaned = pd.read_csv(r'E:\data-science-projects\Rossmann Store Sales\data\processed\store_cleaned.csv')
train_cleaned = pd.read_csv(r'E:\data-science-projects\Rossmann Store Sales\data\processed\train_cleaned.csv')
test_cleaned = pd.read_csv(r'E:\data-science-projects\Rossmann Store Sales\data\processed\test_cleaned.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2128\434394389.py:2: DtypeWarning: Columns (0: StateHoliday) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_cleaned = pd.read_csv(r'E:\data-science-projects\Rossmann Store Sales\data\processed\train_cleaned.csv')

# %%
store_cleaned.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
store_cleaned.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='str')

# %%
store_cleaned.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store_cleaned['CompetitionDistance'].fillna(store_cleaned['CompetitionDistance'].median(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2128\1421491701.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   store_cleaned['CompetitionDistance'].fillna(store_cleaned['CompetitionDistance'].median(), inplace=True)
# 0        1270.0
# 1         570.0
# 2       14130.0
# 3         620.0
# 4       29910.0
#          ...
# ...

# %%
cols = ['CompetitionOpenSinceMonth','CompetitionOpenSinceYear','Promo2SinceWeek','Promo2SinceYear']
store_cleaned[cols].fillna(0, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2128\350806229.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   store_cleaned[cols].fillna(0, inplace=True)
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2SinceWeek  \
# 0                           9.0                    2008.0              0.0
# ...

# %%
store_cleaned['PromoInterval'].fillna('None', inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2128\672978277.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   store_cleaned['PromoInterval'].fillna('None', inplace=True)
# 0                   None
# 1        Jan,Apr,Jul,Oct
# 2        Jan,Apr,Jul,Oct
# 3                   None
# 4                   None
#               ...
# ...

# %%
train_cleaned['Sales'].hist(bins=50)
plt.show()

# %%
train_cleaned[train_cleaned['Sales'] == 0].shape
# Out:
# (172871, 9)

# %%
train_cleaned = train_cleaned[train_cleaned['Sales'] > 0]

# %%
train_df = train_cleaned.merge(store_cleaned, on='Store', how='left')

# %%
train_df['Date'] = pd.to_datetime(train_df['Date'])

train_df['Year'] = train_df['Date'].dt.year
train_df['Month'] = train_df['Date'].dt.month
train_df['Day'] = train_df['Date'].dt.day
train_df['DayOfWeek'] = train_df['Date'].dt.dayofweek

# %%
train_df.head(5)
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1            0
# 1      2          4 2015-07-31   6064        625     1      1            0
# 2      3          4 2015-07-31   8314        821     1      1            0
# 3      4          4 2015-07-31  13995       1498     1      1            0
# 4      5          4 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType  ... CompetitionDistance  \
# 0              1         c  ...              1270.0
# 1              1         a  ...               570.0
# 2              1         a  ...             14130.0
# 3              1         c  ...               620.0
# 4              1         a  ...             29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# ...

# %%
train_df.groupby('Promo')['Sales'].mean()
# Out:
# Promo
# 0    5929.826183
# 1    8228.739731
# Name: Sales, dtype: float64

# %%
train_df.groupby('StoreType')['Sales'].mean()
# Out:
# StoreType
# a     6925.697986
# b    10233.380141
# c     6933.126425
# d     6822.300064
# Name: Sales, dtype: float64

# %%
train_df.groupby('Assortment')['Sales'].mean()
# Out:
# Assortment
# a    6621.523057
# b    8642.503594
# c    7300.843547
# Name: Sales, dtype: float64

# %%
train_df.groupby('Month')['Sales'].mean().plot()
plt.show()

# %%
train_df.groupby('DayOfWeek')['Sales'].mean().plot()
plt.show()

# %%
train_df.groupby(pd.cut(train_df['CompetitionDistance'], bins=5))['Sales'].mean()
# Out:
# CompetitionDistance
# (-55.84, 15188.0]     6961.647012
# (15188.0, 30356.0]    7041.604692
# (30356.0, 45524.0]    6471.923562
# (45524.0, 60692.0]    5980.114445
# (60692.0, 75860.0]    7775.446449
# Name: Sales, dtype: float64

# %%
train_df.corr(numeric_only=True)['Sales'].sort_values(ascending=False)
# Out:
# Sales                        1.000000
# Customers                    0.823552
# Promo                        0.368199
# Promo2SinceWeek              0.095212
# Month                        0.073589
# SchoolHoliday                0.038635
# Year                         0.036151
# CompetitionOpenSinceYear     0.016102
# Store                        0.007723
# Promo2SinceYear             -0.034595
# CompetitionDistance         -0.036453
# CompetitionOpenSinceMonth   -0.043472
# Day                         -0.051865
# Promo2                      -0.127556
# DayOfWeek                   -0.178753
# Open                              NaN
# Name: Sales, dtype: float64

# %%
sns.boxplot(x='StoreType', y='Sales', data=train_df)
plt.show()

# %%
train_df['Sales_log'] = np.log1p(train_df['Sales'])

train_df['Sales_log'].hist(bins=50)
plt.show()

# %%
train_df.groupby('Open')['Sales'].mean()
# Out:
# Open
# 1    6955.959134
# Name: Sales, dtype: float64

# %%
sns.boxplot(x='Promo', y='Sales', data=train_df)
plt.show()

# %%
train_df.groupby(['Promo','StoreType'])['Sales'].mean()
# Out:
# Promo  StoreType
# 0      a             5809.052116
#        b             9567.855955
#        c             6028.547554
#        d             5855.391063
# 1      a             8304.548971
#        b            11311.802796
#        c             8042.788106
#        d             8018.036562
# Name: Sales, dtype: float64

# %%
train_df.groupby(['Year','Month'])['Sales'].mean().plot(figsize=(12,6))
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(train_df.corr(numeric_only=True), cmap='coolwarm')
plt.show()

# %%
sns.boxplot(y=train_df['Sales'])
plt.show()

# %%
train_df.groupby('Store')['Sales'].mean().sort_values(ascending=False).head()
# Out:
# Store
# 817     21757.483418
# 262     20718.515924
# 1114    20666.562500
# 251     19123.068036
# 842     18574.795820
# Name: Sales, dtype: float64
