# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
train_df = pd.read_csv(r'E:\data-science-projects\Rossmann Store Sales\data\processed\train_df.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13568\3729163881.py:1: DtypeWarning: Columns (0: StateHoliday) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv(r'E:\data-science-projects\Rossmann Store Sales\data\processed\train_df.csv')

# %%
X = train_df.drop(['Sales','Sales_log'], axis=1)
y = train_df['Sales_log']
